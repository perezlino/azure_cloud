# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) **Managed tables**
# ##### Objetivos de aprendizaje
# 1. Crear una "managed table" usando Python
# 2. Crear una "managed table" usando SQL
# 3. Efecto de la eliminación de una managed table
# 4. Describir tabla

# %% [markdown]
# #### **Crear una "MANAGED TABLE" usando Python**

# %%
# %python
race_results_df = spark.read.parquet("/FileStore/tables/presentation/race_results")

# %%
# %python
race_results_df.show(truncate=False)
# Out:
# +---------+---------------------+-------------------+----------------+--------------------+-------------+------------------+-----------+----+-----------+-----------+------+--------+-----------------------+
# |race_year|race_name            |race_date          |circuit_location|driver_name         |driver_number|driver_nationality|team       |grid|fastest_lap|race_time  |points|position|created_date           |
# +---------+---------------------+-------------------+----------------+--------------------+-------------+------------------+-----------+----+-----------+-----------+------+--------+-----------------------+
# |2009     |Australian Grand Prix|2009-03-29 06:00:00|Melbourne       |Lewis Hamilton      |44           |British           |McLaren    |18  |39         |\N         |0.0   |null    |2023-06-11 19:27:56.617|
# ...

# %%
# %python
race_results_df.write.format("parquet").saveAsTable("demo.race_results_python")

# %% [markdown]
# <center><img src="https://i.postimg.cc/rF1QNVp5/db90.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/Vkz47xSp/db91.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/QCWLNHcF/db94.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/Z0kGW4LV/db95.png"></center>

# %%
USE demo;
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>demo</td><td>race_results_python</td><td>false</td></tr></tbody></table></div>

# %%
DESCRIBE EXTENDED race_results_python;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
DESCRIBE FORMATTED race_results_python;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
SELECT *
  FROM demo.race_results_python
 WHERE race_year = 2020;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
SELECT CURRENT_DATABASE()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_database()</th></tr></thead><tbody><tr><td>demo</td></tr></tbody></table></div>

# %% [markdown]
# #### **Crear una "MANAGED TABLE" usando Databricks SQL**

# %%
CREATE TABLE demo.race_results_sql
AS
SELECT *
  FROM demo.race_results_python
 WHERE race_year = 2020;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# <center><img src="https://i.postimg.cc/G2hStHnc/db92.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/SsT1Mkmc/db93.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/CMm2fCcb/db96.png"></center>

# %% [markdown]
# <center><img src="https://i.postimg.cc/VLvV9Shp/db97.png"></center>

# %%
DESCRIBE EXTENDED demo.race_results_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
DROP TABLE demo.race_results_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# <center><img src="https://i.postimg.cc/W16gh8nv/db98.png"></center>

# %%
SHOW TABLES IN demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>demo</td><td>race_results_python</td><td>false</td></tr></tbody></table></div>
