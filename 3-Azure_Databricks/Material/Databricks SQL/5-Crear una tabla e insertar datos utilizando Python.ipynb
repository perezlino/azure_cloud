# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) **Crear una tabla e insertar datos utilizando Python**

# %% [markdown]
# Recordar que al utilizar Python para crear tablas estas se crearan como **MANAGED TABLES** por defecto

# %%
employee_data = [(10,"Raj","Kumar","1999","100","M",2000),
                 (20,"Rahul","Rajan","2002","200","f",2000),
                 (30,"Raghav","Manish","2010","100",None,2000),
                 (40,"Raja","Singh","2004","100","F",2000),
                 (50,"Rama","Krish","2008","400","M",2000),
                 (60,"Rasul","Kutty","2014","500","M",2000),
                 (70,"Kumar","Chand","2004","600","M",2000)
                ]
employee_schema = ["employee_id","first_name","last_name","doj",
                   "employee_dept_id","gender","salary"]

df = spark.createDataFrame(data=employee_data, schema=employee_schema)

df.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- doj: string (nullable = true)
#  |-- employee_dept_id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
employee_data = [(80,"Pedro","Rojas","1999","100","M",2000),
                 (90,"Jose","Perez","2002","200","f",2000),
                 (100,"Belen","Oyarce","2010","100",None,2000)
                ]
employee_schema = ["employee_id","first_name","last_name","doj",
                   "employee_dept_id","gender","salary"]

df_new = spark.createDataFrame(data=employee_data, schema=employee_schema)

df_new.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- doj: string (nullable = true)
#  |-- employee_dept_id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)

# %% [markdown]
# #### Ejemplo 1

# %%
# %sql
CREATE DATABASE IF NOT EXISTS demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df.write.format("parquet").saveAsTable("demo.empleados")

# %%
# %sql
SELECT * FROM demo.empleados;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th></tr></thead><tbody><tr><td>80</td><td>Pedro</td><td>Rojas</td><td>1999</td><td>100</td><td>M</td><td>2000</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td><td>2000</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td></tr><tr><td>90</td><td>Jose</td><td>Perez</td><td>2002</td><td>200</td><td>f</td><td>2000</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td></tr><tr><td>100</td><td>Belen</td><td>Oyarce</td><td>2010</td><td>100</td><td>null</td><td>2000</td></tr><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td><td>2000</td></tr></tbody></table></div>

# %% [markdown]
# Mencionar que **insertInto** por defecto ejecuta el modo **append**. No hace falta escribirlo

# %%
df_new.write.format("parquet").insertInto("demo.empleados")

# %%
# %sql
SELECT * FROM demo.empleados
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td><td>2000</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td><td>2000</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td></tr><tr><td>80</td><td>Pedro</td><td>Rojas</td><td>1999</td><td>100</td><td>M</td><td>2000</td></tr><tr><td>90</td><td>Jose</td><td>Perez</td><td>2002</td><td>200</td><td>f</td><td>2000</td></tr><tr><td>100</td><td>Belen</td><td>Oyarce</td><td>2010</td><td>100</td><td>null</td><td>2000</td></tr></tbody></table></div>

# %% [markdown]
# Podemos utilizar el modo **overwrite** y sobreescribirá los nuevos registros en la tabla

# %%
df_new.write.format("parquet").mode('overwrite').insertInto("demo.empleados")

# %%
# %sql
SELECT * FROM demo.empleados
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th></tr></thead><tbody><tr><td>80</td><td>Pedro</td><td>Rojas</td><td>1999</td><td>100</td><td>M</td><td>2000</td></tr><tr><td>90</td><td>Jose</td><td>Perez</td><td>2002</td><td>200</td><td>f</td><td>2000</td></tr><tr><td>100</td><td>Belen</td><td>Oyarce</td><td>2010</td><td>100</td><td>null</td><td>2000</td></tr></tbody></table></div>

# %% [markdown]
# #### Ejemplo 2

# %% [markdown]
# Para este ejemplo vamos a utilizar un particionado sobre la columna **employee_id**

# %%
df.write.format("parquet").partitionBy('employee_id').saveAsTable("demo.empleados_nuevo")

# %% [markdown]
# Podemos ver que al crear una partición sobre una columna, en este caso sobre **employee_id**, al utilizar **saveAsTable** la columna particionada la mueve al final de la tabla

# %%
# %sql
SELECT * FROM demo.empleados_nuevo
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th><th>employee_id</th></tr></thead><tbody><tr><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td><td>2000</td><td>10</td></tr><tr><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td><td>2000</td><td>20</td></tr><tr><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td><td>30</td></tr><tr><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td><td>40</td></tr><tr><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td><td>50</td></tr><tr><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td><td>60</td></tr><tr><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td><td>70</td></tr></tbody></table></div>

# %% [markdown]
# Y el problema que se genera es que al utilizar **insertInto**, esta función trata de insertar nuevos registros según el schema original de la tabla.

# %%
df_new.write.format("parquet").insertInto("demo.empleados_nuevo")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4037067367114995>:1
# ----> 1 df_new.write.format("parquet").mode('append').insertInto("demo.empleados_nuevo")
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:1447, in DataFrameWriter.insertInto(self, tableName, overwrite)
#    1445 if overwrite is not None:
#    1446     self.mode("overwrite" if overwrite else "append")
# -> 1447 self._jwrite.insertInto(tableName)
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: Cannot write incompatible data to table '`spark_catalog`.`demo`.`empleados_nuevo`':
# - Cannot safely cast 'salary': string to bigint.

# %% [markdown]
# Por tanto, para solucionar este problema debemos ordenar las columnas del dataframe que tiene los registros que queremos añadir y mover la columna particionada al final

# %%
df_new = df_new.select("first_name","last_name","doj","employee_dept_id","gender","salary","employee_id")

# %%
df_new.write.format("parquet").insertInto("demo.empleados_nuevo")

# %%
# %sql
SELECT * FROM demo.empleados_nuevo
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th><th>employee_id</th></tr></thead><tbody><tr><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td><td>2000</td><td>10</td></tr><tr><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td><td>2000</td><td>20</td></tr><tr><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td><td>30</td></tr><tr><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td><td>40</td></tr><tr><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td><td>50</td></tr><tr><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td><td>60</td></tr><tr><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td><td>70</td></tr><tr><td>Pedro</td><td>Rojas</td><td>1999</td><td>100</td><td>M</td><td>2000</td><td>80</td></tr><tr><td>Jose</td><td>Perez</td><td>2002</td><td>200</td><td>f</td><td>2000</td><td>90</td></tr><tr><td>Belen</td><td>Oyarce</td><td>2010</td><td>100</td><td>null</td><td>2000</td><td>100</td></tr></tbody></table></div>

# %% [markdown]
# #### Ejemplo 3

# %% [markdown]
# Vamos a ver como lograr de manera dinámica solo insertar aquellos registros para las particiones correctas

# %%
df.write.format("parquet").partitionBy('employee_id').saveAsTable("demo.empleados_ejemplo")

# %%
# %sql
SELECT * FROM demo.empleados_ejemplo
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th><th>employee_id</th></tr></thead><tbody><tr><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td><td>2000</td><td>10</td></tr><tr><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td><td>2000</td><td>20</td></tr><tr><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td><td>30</td></tr><tr><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td><td>40</td></tr><tr><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td><td>50</td></tr><tr><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td><td>60</td></tr><tr><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td><td>70</td></tr></tbody></table></div>

# %% [markdown]
# Para ello vamos a utilizar el siguiente comando:

# %%
# Que por defecto se encuentra establecida en "static"
spark.conf.set("spark.sql.sources.partitionOverwriteMode","dynamic")

# %%
employee_data = [(10,"Alejandra","Soto","2004","300","F",3000),
                 (20,"Tomas","Lino","2010","100","M",4000),
                ]
employee_schema = ["employee_id","first_name","last_name","doj",
                   "employee_dept_id","gender","salary"]

df_new = spark.createDataFrame(data=employee_data, schema=employee_schema)

df_new.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- doj: string (nullable = true)
#  |-- employee_dept_id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
df_new = df_new.select("first_name","last_name","doj","employee_dept_id","gender","salary","employee_id")

# %%
df_new.write.format("parquet").mode('overwrite').insertInto("demo.empleados_ejemplo")

# %%
# Vemos que se sobrescribieron las particiones 10 y 20
# %sql
SELECT * FROM demo.empleados_ejemplo
ORDER BY employee_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th><th>salary</th><th>employee_id</th></tr></thead><tbody><tr><td>Alejandra</td><td>Soto</td><td>2004</td><td>300</td><td>F</td><td>3000</td><td>10</td></tr><tr><td>Tomas</td><td>Lino</td><td>2010</td><td>100</td><td>M</td><td>4000</td><td>20</td></tr><tr><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td><td>2000</td><td>30</td></tr><tr><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td><td>2000</td><td>40</td></tr><tr><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td><td>2000</td><td>50</td></tr><tr><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td><td>2000</td><td>60</td></tr><tr><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td><td>2000</td><td>70</td></tr></tbody></table></div>
