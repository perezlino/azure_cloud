# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Titulos Markdown

# %%
# Titulo
## Titulo
### Titulo
#### Titulo
* Opción 1
* Opción 2

# %% [markdown]
# # Titulo
# ## Titulo
# ### Titulo
# #### Titulo
# * Opción 1
# * Opción 2
