# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) **Funciones de texto**
#
# Podemos utilizar las funciones de texto de HIVE

# %% [markdown]
# Para revisar ejemplos:
# 1. Crear base de datos **processed**
#
#     *   Ejecutar notebook de Proyecto 1 --> desarrollo --> Paso 2 --> Parte C --> Paso 2.10 --> Paso 2.10.2 --> Paso 2.0
# ```
# ```
# 2. Ejecutar notebook de Proyecto 1 --> desarrollo --> Paso 2 --> Parte C --> Paso 2.10 --> Paso 2.10.2 --> Paso 2.4

# %%
USE f1_processed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### **CONCAT**

# %%
SELECT *, CONCAT(driver_ref, '-', code) AS new_driver_ref
  FROM drivers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### **SPLIT**

# %%
SELECT *, SPLIT(name, ' ')[0] forename, SPLIT(name, ' ')[1] surname
  FROM drivers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
