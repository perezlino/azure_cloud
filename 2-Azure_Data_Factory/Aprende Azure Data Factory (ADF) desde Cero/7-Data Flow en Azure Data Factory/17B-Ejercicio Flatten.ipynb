# %% [markdown]
# ### Ejercicio - Flatten

# %%
Se requiere cargar archivos en formato JSON (documento único, documento por línea y Matriz) hacia Azure SQL.

Para realizar la carga de datos se tiene que utilizar la transformación de "Flatten".

# %%
             SOURCE                            UNION                     SELECT                    UNION                      SINK
 _______________________________          ________________          ________________          ________________          _________________
|                               |        |                |        |                |        |                |        |                 |      
|  sourceJsonDocumentoPorLinea  |--------|   UnionJson1   |--------|   SelectJson   |--------|   UnionJson2   |--------|  sinkAutomovil  |
|_______________________________| +      |________________| +      |________________| +      |________________| +      |_________________|
                                              |          
           SOURCE                             |
 __________________________                   |
|                          |                  |   
| sourceJsonDocumentoUnico |------------------'
|__________________________| 

      SOURCE                     FLATTEN                    FLATTEN
 __________________          ________________          _________________        
|                  |        |                |        |                 |      
| sourceJsonMatriz |--------|  FlattenColor  |--------|  FlattenModelo  |
|__________________| +      |________________| +      |_________________|

# %% [markdown]
# ##### sourceJsonDocumentoPorLinea
#
# - Utilizamos "Inline Dataset" (obtenemos el mismo resultado que utilizando "Dataset", no se cual es la real diferencia)
# - Inline Dataset Type: escogemos el tipo de origen
# - Linked service: escogemos el Linked Service de origen, y este apunta hacia Azure Blob Storage, a una ruta especifica
# - Debug mode: al activarlo nos permitirá acceder a las opciones de Projection y Data preview.
#
# <center><img src="https://i.postimg.cc/2jhcY2R9/adf153.png"></center>
#
# - Si se selecciona un archivo JSON como origen, debemos indicar el tipo de formato del documento.
# - Document form: - Single document
#                  - Document per line
#                  - Array of documents
#
# <center><img src="https://i.postimg.cc/sDKJfLnm/adf154.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/268kYV32/adf155.png"></center>
#
# - Importamos el schema
#
# <center><img src="https://i.postimg.cc/nr64D8D9/adf162.png"></center>
# <center><img src="https://i.postimg.cc/Bn5TXVQt/adf163.png"></center>
#
#
# ##### sourceJsonDocumentoUnico
#
# - Utilizamos "Inline Dataset" (obtenemos el mismo resultado que utilizando "Dataset", no se cual es la real diferencia)
# - Inline Dataset Type: escogemos el tipo de origen
# - Linked service: escogemos el Linked Service de origen, y este apunta hacia Azure Blob Storage, a una ruta especifica
# - Debug mode: al activarlo nos permitirá acceder a las opciones de Projection y Data preview.
#
# <center><img src="https://i.postimg.cc/90XHTSyb/adf157.png"></center>
#
# - Si se selecciona un archivo JSON como origen, debemos indicar el tipo de formato del documento.
# - Document form: - Single document
#                  - Document per line
#                  - Array of documents
#
# <center><img src="https://i.postimg.cc/pXxpcXJc/adf156.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/Y0PD9yRh/adf158.png"></center>
#
# - Importamos el schema
#
# <center><img src="https://i.postimg.cc/nr64D8D9/adf162.png"></center>
# <center><img src="https://i.postimg.cc/Bn5TXVQt/adf163.png"></center>
#
#
# ##### sourceJsonMatriz
#
# - Utilizamos "Inline Dataset" (obtenemos el mismo resultado que utilizando "Dataset", no se cual es la real diferencia)
# - Inline Dataset Type: escogemos el tipo de origen
# - Linked service: escogemos el Linked Service de origen, y este apunta hacia Azure Blob Storage, a una ruta especifica
# - Debug mode: al activarlo nos permitirá acceder a las opciones de Projection y Data preview.
#
# <center><img src="https://i.postimg.cc/T1r8zxfT/adf160.png"></center>
#
# - Si se selecciona un archivo JSON como origen, debemos indicar el tipo de formato del documento.
# - Document form: - Single document
#                  - Document per line
#                  - Array of documents
#
# <center><img src="https://i.postimg.cc/5t7fgfNG/adf159.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/cJZv21WL/adf161.png"></center>
#
# - Importamos el schema
#
# <center><img src="https://i.postimg.cc/nr64D8D9/adf162.png"></center>
# <center><img src="https://i.postimg.cc/Bn5TXVQt/adf163.png"></center>
#
#
# ##### FlattenColor
#
# <center><img src="https://i.postimg.cc/Z5Vr8sXR/adf165.png"></center>
# <center><img src="https://i.postimg.cc/vB6fdYTg/adf166.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/W3PbhTSJ/adf167.png"></center>
#
#
# ##### FlattenModelo
#
# <center><img src="https://i.postimg.cc/2SwP4mzZ/adf168.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/QCQ6hkCT/adf169.png"></center>
#
#
# ##### UnionJson1
#
# - Escogemos "Union by: Name" dado que los archivos los uniremos por nombre de columna.
#
# <center><img src="https://i.postimg.cc/3RR7yNmN/adf170.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/Zqfns1L9/adf171.png"></center>
#
#
# ##### SelectJson
#
# - Lo que hacemos es EXTRAER los campos de 'Email' y 'Telefono' desde 'Contacto'. De esta manera tendrán columnas independientes
#
# <center><img src="https://i.postimg.cc/zf9v1T95/adf172.png"></center>
#
# - Visualizamos los datos
#
# <center><img src="https://i.postimg.cc/yNX122Xh/adf173.png"></center>
#
#
# ##### UnionJson2
#
# - Escogemos "Union by: Name" dado que los archivos los uniremos por nombre de columna.
#
# <center><img src="https://i.postimg.cc/R0VC5XPj/adf174.png"></center>
#
#
# ##### sinkAutomovil
#
# - Utilizamos "Inline Dataset" (obtenemos el mismo resultado que utilizando "Dataset", no se cual es la real diferencia)
# - Inline Dataset Type: escogemos el tipo de salida
# - Linked service: escogemos el Linked Service de destino, y este apunta hacia Azure SQL Database, a una base de datos especifica
# - Debug mode: al activarlo nos permitirá acceder a las opciones de Mapping y Data preview. Además permitirá cargar los schemas
#               y tablas de la base de datos.
#
# <center><img src="https://i.postimg.cc/C5tnd92B/adf175.png"></center>
#
# - Se cargará en la tabla que creamos 'Automovil'
#
# <center><img src="https://i.postimg.cc/6pKbQSx1/adf176.png"></center>
# <center><img src="https://i.postimg.cc/j5DZ9YyC/adf177.png"></center>
#
#
# ##### Ejecución del Pipeline y resultados
#
# - Despues de haber finalizado nuestro Data Flow, lo ejecutaremos dentro de una actividad "Data Flow" desde un Pipeline
# - Podemos ver que se ha cargado en la tabla
#
# <center><img src="https://i.postimg.cc/9fnBygs2/adf178.png"></center>
